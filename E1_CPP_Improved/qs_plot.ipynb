# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('qs_data.csv')
plt.plot(df['Ip_Size'], df['Time'], marker = '.')
plt.title('Quick Sort Performance')
plt.xlabel('Input Size')
plt.ylabel('Time Taken')
plt.xscale('log')
